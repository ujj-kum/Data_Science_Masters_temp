# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples=1000, n_features=2, n_classes=2, n_clusters_per_class=2, n_redundant=0)

# %%
X.shape
# Out:
# (1000, 2)

# %%
y.shape
# Out:
# (1000,)

# %%
X[0], X[1]
# Out:
# (array([-1.04302957,  2.8803772 ]), array([ 2.58949938, -1.29143098]))

# %%
df = pd.DataFrame(X, columns=['X1', 'X2'])
df.head()
# Out:
#          X1        X2
# 0 -1.043030  2.880377
# 1  2.589499 -1.291431
# 2  0.021490 -1.119687
# 3 -0.578529 -1.002072
# 4 -1.021686 -1.029472

# %%
df['Target'] = y
df.head()
# Out:
#          X1        X2  Target
# 0 -1.043030  2.880377       0
# 1  2.589499 -1.291431       1
# 2  0.021490 -1.119687       1
# 3 -0.578529 -1.002072       0
# 4 -1.021686 -1.029472       0

# %%
sns.scatterplot(df.iloc[:,:-1])
# Out:
# <AxesSubplot: >

# %%
sns.scatterplot(x=df.iloc[:,0], y=df.iloc[:,1], hue=df['Target'])
# Out:
# <AxesSubplot: xlabel='X1', ylabel='X2'>
